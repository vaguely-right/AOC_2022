# %%
from aocd import get_data
day1 = get_data(day=1,year=2022)

# %%
day1 = [i.split('\n') for i in day1.split('\n\n')]
day1
# Out:
# [['10062', '15651', '1271', '14355', '7220'],
#  ['4878',
#   '1754',
#   '8466',
#   '4741',
#   '2582',
#   '3003',
#   '5327',
#   '3172',
#   '1327',
#   '6310'],
#  ['22413', '4145', '22294'],
#  ['23108', '30453'],
#  ['2084',
#   '3496',
#   '4800',
#   '1388',
#   '8728',
#   '6380',
#   '6397',
#   '2558',
#   '2120',
#   '6159'],
#  ['25265', '20200', '2083'],
#  ['7424',
#   '5830',
#   '2575',
#   '2825',
#   '2234',
#   '6106',
#   '5505',
#   '2847',
#   '2059',
#   '7145',
#   '7223'],
#  ['58621'],
#  ['2926', '9188', '7432', '1639', '7420', '1161', '5517', '2703', '5446'],
#  ['2457',
#   '5814',
#   '1294',
#   '3280',
#   '8531',
#   '8214',
#   '4736',
#   '1964',
#   '1155',
#   '2380'],
#  ['2812',
#   '1827',
#   '5533',
#   '1756',
#   '1491',
#   '4127',
#   '6452',
#   '5935',
#   '1415',
#   '6221',
#   '3489',
#   '2681',
#   '4849',
#   '5250'],
#  ['2922', '10365', '5819', '10227', '2962', '2702'],
#  ['2982', '9254', '14137', '5026', '9374'],
# ...

# %%
day1 = [[int(j) for j in i] for i in day1]

# %%
[[int(j) for j in i] for i in day1]
# Out:
# [[10062, 15651, 1271, 14355, 7220],
#  [4878, 1754, 8466, 4741, 2582, 3003, 5327, 3172, 1327, 6310],
#  [22413, 4145, 22294],
#  [23108, 30453],
#  [2084, 3496, 4800, 1388, 8728, 6380, 6397, 2558, 2120, 6159],
#  [25265, 20200, 2083],
#  [7424, 5830, 2575, 2825, 2234, 6106, 5505, 2847, 2059, 7145, 7223],
#  [58621],
#  [2926, 9188, 7432, 1639, 7420, 1161, 5517, 2703, 5446],
#  [2457, 5814, 1294, 3280, 8531, 8214, 4736, 1964, 1155, 2380],
#  [2812,
#   1827,
#   5533,
#   1756,
#   1491,
#   4127,
#   6452,
#   5935,
#   1415,
#   6221,
#   3489,
#   2681,
#   4849,
#   5250],
#  [2922, 10365, 5819, 10227, 2962, 2702],
#  [2982, 9254, 14137, 5026, 9374],
#  [5933,
#   2888,
#   2250,
#   4514,
#   1825,
#   5616,
#   3497,
#   2988,
#   1181,
#   3836,
#   1032,
#   5847,
#   5383],
#  [5044, 5922, 3155, 1610, 5510, 5016, 6666, 7024, 4649, 2764, 6444],
#  [12932],
#  [4764,
#   4285,
#   1278,
#   5020,
#   5917,
#   1888,
#   4757,
#   6323,
#   5067,
#   1314,
#   1530,
#   5748,
# ...

# %%
elves = [sum(i) for i in day1]

# %%
max(elves)
# Out:
# 70613

# %%
elves.sort(reverse=True)

# %%
elves
# Out:
# [70613,
#  68330,
#  66862,
#  66459,
#  65939,
#  64875,
#  62472,
#  61690,
#  61660,
#  61586,
#  61576,
#  61472,
#  61139,
#  61011,
#  60824,
#  60742,
#  60621,
#  60086,
#  60049,
#  59597,
#  59394,
#  59320,
#  59312,
#  59301,
#  59084,
#  59077,
#  58973,
#  58633,
#  58621,
#  58500,
#  58206,
#  58171,
#  57887,
#  57671,
#  57449,
#  57223,
#  56849,
#  56760,
#  56680,
#  56577,
#  56445,
#  56328,
#  55980,
#  55975,
#  55850,
#  55244,
#  55167,
#  55042,
#  55007,
#  54909,
#  54699,
#  54687,
#  54621,
#  54588,
#  54497,
#  54447,
#  54324,
#  54179,
#  54122,
#  54053,
#  54040,
#  53838,
#  53804,
#  53774,
#  53703,
#  53561,
#  53555,
#  53500,
#  53324,
#  53094,
#  53078,
#  52999,
#  52812,
#  52721,
#  52713,
#  52593,
#  52556,
#  52538,
#  52524,
#  52490,
#  52464,
#  52453,
#  52450,
#  52435,
#  52381,
#  52321,
#  52091,
#  51981,
#  51881,
#  51845,
#  51773,
#  51765,
#  51687,
#  51429,
#  51428,
#  51413,
#  51337,
#  51316,
#  51292,
#  51246,
# ...

# %%
sum(elves[0:3])
# Out:
# 205805
